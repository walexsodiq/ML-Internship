# %% [markdown]
# <a href="https://colab.research.google.com/github/walexsodiq/ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/walexsodiq/ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Refresh / Content Opportunity Scoring
#
# Why - This can help me identify a page strong visibility while signs of decline are there

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Research question:
#
# Which pages should a content team review first for possible refresh opportunities based on observable search and engagement signals?
#
# Decision improved:
#
# The decision is which pages should receive attention first when the team has limited review capacity.
#
# Who acts:
#
# A content strategist or SEO reviewer would use the ranked list to decide whether a page should be refreshed, expanded, monitored, or left unchanged.
#
# Cost of a wrong recommendation:
#
# A false positive could waste time updating a page that did not need changes. A false negative could cause the team to miss a page that was losing visibility or an opportunity to improve performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

url = "https://raw.githubusercontent.com/walexsodiq/ML-Internship/9e26bfb333f942b759d969adbd25f2d2ddbe425f/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

print("Number of pages:", len(df))

print("\nTrend direction counts:")
print(df["trend_direction"].value_counts())

visible = df[df["impressions_90d"] > 0]

print("\nPages with impressions:", len(visible))

print("\nAverage 90d impressions:", round(df["impressions_90d"].mean(), 2))
print("Average CTR:", round(df["ctr"].mean(), 4))
# Out:
# Number of pages: 30000
#
# Trend direction counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Pages with impressions: 30000
#
# Average 90d impressions: 5200.37
# Average CTR: 0.5107

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project can identify patterns and rank pages for review using observed search and engagement signals. The output will be decision-support: it helps humans decide where to investigate first.
#
# I can say that certain signals are associated with pages that appear to have lower performance or opportunity. I cannot claim that the model proves Google ranking factors, guarantees traffic recovery, or proves that a refresh will cause improvement. The analysis is observational and does not establish causation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
